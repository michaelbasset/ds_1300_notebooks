# %% [markdown]
# Final Project Code

# %% [markdown]
# Calculations: items with trackers

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('project2.csv')

# %%
facts=pd.read_csv('project2.csv')
facts.head(6)
# Out:
#    Pulls/Takes  Answering Machine  Cell Phone  Device (Other)  Pager  \
# 0            1                  8       30124              45     62
# 1          100                  8       31835              47     63
# 2          150                  8       32995              48     67
# 3          200                  8       33864              48     68
# 4          250                  9       37144              49     70
# 5          252                  9       37199              49     70
#
#    Phone Accessories  Walkie Talkie  Other Eletronic  Camera  Computer  ...  \
# 0               2336             99             1339     958       735  ...
# 1               2534            100             1422     999       774  ...
# 2               2679            106             1471    1022       795  ...
# 3               2830            110             1518    1033       847  ...
# 4               3205            118             1670    1101       939  ...
# ...

# %%
facts[facts.columns[1:]]
# Out:
#    Answering Machine  Cell Phone  Device (Other)  Pager  Phone Accessories  \
# 0                  8       30124              45     62               2336
# 1                  8       31835              47     63               2534
# 2                  8       32995              48     67               2679
# 3                  8       33864              48     68               2830
# 4                  9       37144              49     70               3205
# 5                  9       37199              49     70               3210
#
#    Walkie Talkie  Other Eletronic  Camera  Computer  Motor Scooter  ...  \
# 0             99             1339     958       735              1  ...
# 1            100             1422     999       774              1  ...
# 2            106             1471    1022       795              1  ...
# 3            110             1518    1033       847              1  ...
# 4            118             1670    1101       939              1  ...
# ...

# %%
facts['Totals']=[facts.loc[x,facts.columns[1:]].sum() for x in range(len(facts))]

# %%
facts
# Out:
#    Pulls/Takes  Answering Machine  Cell Phone  Device (Other)  Pager  \
# 0            1                  8       30124              45     62
# 1          100                  8       31835              47     63
# 2          150                  8       32995              48     67
# 3          200                  8       33864              48     68
# 4          250                  9       37144              49     70
# 5          252                  9       37199              49     70
#
#    Phone Accessories  Walkie Talkie  Other Eletronic  Camera  Computer  ...  \
# 0               2336             99             1339     958       735  ...
# 1               2534            100             1422     999       774  ...
# 2               2679            106             1471    1022       795  ...
# 3               2830            110             1518    1033       847  ...
# 4               3205            118             1670    1101       939  ...
# ...

# %%
facts['color']=['k','r','b','g','c','y']

# %%
a=36558
b=38703
c=40198
d=41433
e=45759
f=45827

# %% [markdown]
# Total growth in lost items

# %%
f-a
# Out:
# 9269

# %%
sub = facts[['Pulls/Takes','Totals']]

# %%
sub.plot.scatter(x='Pulls/Takes', y='Totals')
# Out:
# <AxesSubplot:xlabel='Pulls/Takes', ylabel='Totals'>

# %%
X=sub['Pulls/Takes'].values
Y=sub['Totals'].values

# %%
def lin_reg(x,y):
    # Calculate the average x and y
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)): # This represents our sums
        num = num + (x[i] - x_avg)*(y[i] - y_avg) # Our numerator
        den = den + (x[i] - x_avg)**2 # Our denominator
    # Calculate slope
    m = num / den
    # Calculate intercept
    b = y_avg - m*x_avg

    print (m, b)
    
    # Calculate our predicted y values
    y_pred = m*x + b
    
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 37.01400532492283 35507.94215422476

# %%
max(Y_pred)
# Out:
# 44835.47149610531

# %%
min(Y_pred)
# Out:
# 35544.95615954968

# %%
min(sub['Totals'])
# Out:
# 36532.0

# %%
max(sub['Totals'])
# Out:
# 45801.0

# %%
sub
# Out:
#    Pulls/Takes   Totals
# 0            1  36532.0
# 1          100  38677.0
# 2          150  40172.0
# 3          200  41407.0
# 4          250  45733.0
# 5          252  45801.0

# %%
sub.plot.scatter(x='Pulls/Takes', y='Totals',xlabel='Pulls/Takes', ylabel= 'Number Of Lost Items', title= 'Lost Subway Items With Trackers') # best fit line
plt.plot([min(sub['Pulls/Takes'].values), max(sub['Pulls/Takes'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %%
facts[['Answering Machine','Cell Phone','Device (Other)','Pager','Phone Accessories', 'Walkie Talkie', 'Other Eletronic', 'Camera', 'Computer', 'Motor Scooter', 'Activity Trackers', 'Tablets', 'NAV System']].plot.bar(stacked=True,figsize=(10,10),color=facts['color'])
# Out:
# <AxesSubplot:>
